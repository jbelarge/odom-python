# %%
import numpy as np
import os
filepath_syn = './data/trolley/data1/syn/imu1.csv'
filepath_raw = './data/trolley/data1/raw/imu1.csv'
syn = np.loadtxt(filepath_syn,delimiter=',')
raw = np.loadtxt(filepath_raw,delimiter=',')

# %% [markdown]
# Time
#
# attitude_roll(radians)
#
# attitude_pitch(radians)
#
# attitude_yaw(radians)
#
# rotation_rate_x(radians/s)
#
# rotation_rate_y(radians/s)
#
# rotation_rate_z(radians/s)
#
# gravity_x(G)
#
# gravity_y(G)
#
# gravity_z(G)
#
# user_acc_x(G)
#
# user_acc_y(G)
#
# user_acc_z(G)
#
# magnetic_field_x(microteslas)
#
# magnetic_field_y(microteslas)
#
# magnetic_field_z(microteslas)

# %%
filepath_syn = './data/trolley/data1/syn/vi1.csv'
filepath_raw = './data/trolley/data1/raw/vi1.csv'
syn_truth = np.loadtxt(filepath_syn,delimiter=',')
raw_truth = np.loadtxt(filepath_raw,delimiter=',')

# %% [markdown]
# Time
#
# Header
#
# translation.x
#
# translation.y
#
# translation.z
#
# rotation.x
#
# rotation.y
#
# rotation.z
#
# rotation.w

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(syn_truth[1200:1400,4],syn_truth[1200:1400,3],syn_truth[1200:1400,2])
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()
